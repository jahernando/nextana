# %% [markdown]
# # Study the Kr response per PMT
#
# JAH 1/05/2025

# %% [markdown]
# ### imports

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os

import numpy             as np
import pandas            as pd
import tables            as tb
from   scipy             import stats
from   scipy             import optimize

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

plt.rcParams['image.cmap'] = 'rainbow'

# %%
from invisible_cities.io  . pmaps_io        import load_pmaps, load_pmaps_as_df

# %% [markdown]
# ### configuration

# %% [markdown]
# ### load data

# %%
path_data =  "/Users/hernando/work/investigacion/NEXT/data/NEXT100/data"
path_run  =  "/15267/hdf5/prod/v2.3.1/20250429/irene/trigger1/ldc1"

# %%
path = path_data + path_run
filenames = os.listdir(path)
filenames = [os.path.join(path, f) for f in filenames]
#for f in filenames: print(f)

# %% [markdown]
# ### Ana

# %%
## reading as DF

s1, s2, si, s1_pmt, s2_pmt = load_pmaps_as_df(filenames[0])

# %%
s1_pmt.event.unique()
# Out:
# array([31068, 31075, 31082, 31096, 31117, 31124, 31138, 31145, 31166,
#        31173, 31180, 31208, 31215, 31222, 31229, 31250, 31264, 31271,
#        31278, 31299, 31313, 31320, 31327, 31334, 31341, 31348, 31355,
#        31362, 31369, 31376, 31390, 31404, 31411, 31425, 31446, 31453,
#        31460, 31467, 31474, 31481, 31495, 31502, 31509, 31516, 31523,
#        31530, 31544, 31551, 31558, 31565, 31572, 31579, 31586, 31593,
#        31600, 31635, 31649, 31677, 31691, 31698, 31705, 31712, 31719,
#        31733, 31740, 31747, 31754, 31761, 31775, 31789, 31796, 31803,
#        31810, 31817])

# %%
## reading as pmaps

pmaps = load_pmaps(filename)
evt = pmaps[evt_number]
evt.s1s # una lista de los s1s
evt.s2s # una lista de los s2s
